# %%
class BookList():
    def __init__(self, bookName, authorName, year, next=None):
        self.bookName = bookName
        self.authorName = authorName
        self.year = int(year)
        self.next = next
class Book():
    def __init__(self):
        self.head = None
    def insertBook(self, bookName, authorName, year):
        new_node = BookList(bookName, authorName, year)
        if self.head is None:
            self.head = new_node
        else:
            node = self.head
            while node.next:
                node = node.next
            node.next = new_node
    def printLL(self):
        if self.head is None:
            print(None)
        else:
            node = self.head
            while node:
                print(f'name: {node.authorName}, author: {node.authorName}, year: {node.year}', end= '\n')
                node = node.next
    def removeBook(self, name_book):
        if self.head is None:
            return None
        else:
            node = self.head
            prev = Node(None,None, None, self.head)
            while node.bookName != name_book and node.next:
                node = node.next
                prev = prev.next
            if node = self.head:
                self.head.next = node.next
            else:
                prev.next = node.next
    def listBook(self):
        dict = {}
        if self.head is None:
            return dict
        else:
            node = self.head
            while node:
                dict[node.authorName].add(node.bookName)
                node = node.next
        return dict
    def removeDuplication(self):
        if self.head is None:
            return None
        else:
            a = [0]*1000000
            node = self.head
            prev = Node(None,None, None, self.head)
            while node:
                tmp = node.next
                if a[node.year] != 0:
                    self.removeBook(node.bookName)
                else:
                    a[node.year] += 1
                node = node.next
    def display(self):
        if self.head is None:
            return None
        else:
            node = self.head
            while node:
                print(node.authorName)
                node = node.next
        
                
a = Book()
a.insertBook('a', '1', 1)
a.insertBook('b', '2', 2)
a.insertBook('a', '1', 1)
a.insertBook('c', '3', 3)
a.insertBook('d', '4', 4)
a.removeBook('d')
a.display()
